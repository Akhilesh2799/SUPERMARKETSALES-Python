# %% [markdown]
# ##                        ***PYTHON ENDCAPTONE -2***

# %% [markdown]
# # **Supermarket_Sales**

# %% [markdown]
# **IMPORTING LIBRARIES**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **IMPORTING THE DATA**

# %%
df = pd.read_csv('/content/supermarket_sales - Sheet1.csv')

# %% [markdown]
# **DATA**

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# **TO FIND THE NULL VALUES**

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# **DIFFERENT COLUMNS (OR) COLUMN NAMES**

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %% [markdown]
# **CALCULATING STATISTICAL METHODS OF THE DATA**

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %% [markdown]
# **DTYPES OF THE COLUMNS**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %% [markdown]
# **DISPLAY TOP 5 ROWS**

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# **CHECK ANY DUPLICATE VALUES IN THE DATA**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **PRINT DATATYPES OF THE COLUMNS**

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
Product_Count = df['Product line'].value_counts()

# %% [markdown]
# # **PRODUCT COUNTS**

# %%
Product_Count
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %% [markdown]
# Fashion accessories are maximum & Health and beauty are in minimum.
# You can see the chart for easy understanding.

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=df,x='Product line')
plt.show()

# %%
Member_ship = df[(df['Customer type']=='Member')]

# %% [markdown]
# # **MEMBER SHIP**

# %%
Member_ship
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 3    123-19-1176      A     Yangon        Member    Male
# 6    355-53-5943      A     Yangon        Member  Female
# 8    665-32-9167      A     Yangon        Member  Female
# 9    692-92-5582      B   Mandalay        Member  Female
# ..           ...    ...        ...           ...     ...
# 988  267-62-7380      C  Naypyitaw        Member    Male
# 989  430-53-4718      B   Mandalay        Member    Male
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 0         Health and beauty       74.69         7  26.1415  548.9715
# 3         Health and beauty       58.22         8  23.2880  489.0480
# 6    Electronic accessories       68.84         6  20.6520  433.6920
# ...

# %%
Membership_Gender = Member_ship['Gender'].value_counts()

# %%
Membership_Gender
# Out:
# Female    261
# Male      240
# Name: Gender, dtype: int64

# %% [markdown]
# Out of 501,261 are females and remaining 240 members are males.

# %%
Normal = df[(df['Customer type']=='Normal')]

# %% [markdown]
# # **NORMAL**

# %%
Normal
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# 5    699-14-3026      C  Naypyitaw        Normal    Male
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# ..           ...    ...        ...           ...     ...
# 992  745-74-0715      A     Yangon        Normal    Male
# 993  690-01-6631      B   Mandalay        Normal    Male
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 998  347-56-2442      A     Yangon        Normal    Male
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# ...

# %%
Normal_Gender = Normal['Gender'].value_counts()

# %%
Normal_Gender
# Out:
# Male      259
# Female    240
# Name: Gender, dtype: int64

# %% [markdown]
# Out of 499,259 are males and remaining are females.Here males are maximum

# %%
Most_Ratings=df[(df['Rating'] > 7)]

# %% [markdown]
# # **MOST RATINGS**

# %%
Most_Ratings
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# ..           ...    ...        ...           ...     ...
# 982  139-32-4183      A     Yangon        Member  Female
# 985  374-38-5555      B   Mandalay        Normal  Female
# 989  430-53-4718      B   Mandalay        Member    Male
# 992  745-74-0715      A     Yangon        Normal    Male
# 997  727-02-1313      A     Yangon        Member    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 0         Health and beauty       74.69         7  26.1415  548.9715
# 1    Electronic accessories       15.28         5   3.8200   80.2200
# 2        Home and lifestyle       46.33         7  16.2155  340.5255
# ...

# %%
MostRatings_city = Most_Ratings['City'].value_counts()

# %%
MostRatings_city
# Out:
# Yangon       172
# Naypyitaw    167
# Mandalay     142
# Name: City, dtype: int64

# %% [markdown]
# Yagon city has the highest ratings

# %%
sns.countplot(data=df,x='City')
# Out:
# <Axes: xlabel='City', ylabel='count'>

# %%
MostRatings_product = Most_Ratings['Product line'].value_counts()

# %% [markdown]
# # **MOST RATED PRODUCTS**

# %%
MostRatings_product
# Out:
# Food and beverages        93
# Fashion accessories       86
# Health and beauty         79
# Electronic accessories    78
# Home and lifestyle        75
# Sports and travel         70
# Name: Product line, dtype: int64

# %% [markdown]
# Food and beverages are most rated products.
# Food and beverages are high & Sports and travel are in least

# %%
Mostly_sold_products = (df['Product line'])

# %%
Mostly_sold_products.value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %% [markdown]
# Fashion accessories are mostly sold products

# %%
Male_purchased_products = df[(df['Gender']=='Male')]

# %% [markdown]
# # **MOSTLY PURCHASED PRODUCTS BY MEN**

# %%
Male_purchased_products
# Out:
#       Invoice ID Branch       City Customer type Gender  \
# 2    631-41-3108      A     Yangon        Normal   Male
# 3    123-19-1176      A     Yangon        Member   Male
# 4    373-73-7910      A     Yangon        Normal   Male
# 5    699-14-3026      C  Naypyitaw        Normal   Male
# 11   529-56-3974      B   Mandalay        Member   Male
# ..           ...    ...        ...           ...    ...
# 992  745-74-0715      A     Yangon        Normal   Male
# 993  690-01-6631      B   Mandalay        Normal   Male
# 995  233-67-5758      C  Naypyitaw        Normal   Male
# 997  727-02-1313      A     Yangon        Member   Male
# 998  347-56-2442      A     Yangon        Normal   Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 2        Home and lifestyle       46.33         7  16.2155  340.5255
# 3         Health and beauty       58.22         8  23.2880  489.0480
# 4         Sports and travel       86.31         7  30.2085  634.3785
# ...

# %%
Mostlypurchased_Male =Male_purchased_products ['Product line'].value_counts()

# %%
Mostlypurchased_Male
# Out:
# Health and beauty         88
# Electronic accessories    86
# Food and beverages        84
# Fashion accessories       82
# Home and lifestyle        81
# Sports and travel         78
# Name: Product line, dtype: int64

# %% [markdown]
# Mens are mostly concentrated on both Health and beauty products.
# Mens mostly purchased the Health and beauty products

# %%
Female_purchased_products = df[(df['Gender']=='Female')]

# %% [markdown]
# # **MOSTLY PURCHASED PRODUCTS BY FEMALE**

# %%
Mostlypurchased_Female =Female_purchased_products ['Product line'].value_counts()

# %%
Mostlypurchased_Female
# Out:
# Fashion accessories       96
# Food and beverages        90
# Sports and travel         88
# Electronic accessories    84
# Home and lifestyle        79
# Health and beauty         64
# Name: Product line, dtype: int64

# %% [markdown]
# Females are mostly purchased the Fashion accessories.They only concentrate on the fashion.

# %%
Payment_type = df['Payment'].value_counts()

# %% [markdown]
# # **PAYMENT**

# %%
Payment_type
# Out:
# Ewallet        345
# Cash           344
# Credit card    311
# Name: Payment, dtype: int64

# %%
sns.countplot(data=df,x='Payment')
# Out:
# <Axes: xlabel='Payment', ylabel='count'>

# %%
Preferred_branch = df['Branch'].value_counts()

# %% [markdown]
# # **BRANCH PREFERRED**

# %%
Preferred_branch
# Out:
# A    340
# B    332
# C    328
# Name: Branch, dtype: int64

# %% [markdown]
# Branch A is preferred

# %%
sns.countplot(data=df,x='Branch')
# Out:
# <Axes: xlabel='Branch', ylabel='count'>

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df1 = df.drop(['Invoice ID', 'Date','Time'], axis=1)

# %% [markdown]
# DELETE THE UNNECESSARY COLUMNS

# %%
df1
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total      Payment    cogs  \
# 0         74.69         7  26.1415   548.9715      Ewallet  522.83
# ...

# %%
df1.isnull().sum()
# Out:
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df1['Branch']=lb.fit_transform(df1['Branch'])
df1['City']=lb.fit_transform(df1['City'])
df1['Customer type']=lb.fit_transform(df1['Customer type'])
df1['Gender']=lb.fit_transform(df1['Gender'])
df1['Product line']=lb.fit_transform(df1['Product line'])
df1['Payment']=lb.fit_transform(df1['Payment'])
X = df1.drop('Quantity', axis=1)
y = df1['Quantity']

# %% [markdown]
# Fitting the columns with LabelEncoder

# %%
x
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price   Tax 5%      Total      Payment    cogs  \
# 0         74.69  26.1415   548.9715      Ewallet  522.83
# ...

# %%
y
# Out:
# 0       7
# 1       5
# 2       7
# 3       8
# 4       7
#        ..
# 995     1
# 996    10
# 997     1
# 998     1
# 999     7
# Name: Quantity, Length: 1000, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
x_train
# Out:
#      Branch  City  Customer type  Gender  Product line  Unit price  Tax 5%  \
# 347       2     1              0       0             4       89.25  35.700
# 632       0     2              0       1             2       83.77   8.377
# 10        1     0              0       0             1       14.48   2.896
# 688       2     1              0       1             5       72.88   7.288
# 630       0     2              1       1             5       64.19  32.095
# ..      ...   ...            ...     ...           ...         ...     ...
# 896       2     1              1       1             1       60.74  21.259
# 917       0     2              1       0             1       94.67  18.934
# 73        2     1              1       0             0       75.91  22.773
# 933       2     1              1       1             3       64.08  22.428
# 303       0     2              1       0             0       51.19  10.238
#
# ...

# %%
x_test
# Out:
#      Branch  City  Customer type  Gender  Product line  Unit price   Tax 5%  \
# 575       1     0              0       1             1       81.31  28.4585
# 210       0     2              1       1             0       26.23  11.8035
# 544       1     0              1       0             2       71.20   3.5600
# 33        0     2              1       1             3       96.58   9.6580
# 225       2     1              0       0             5       87.16   8.7160
# ..      ...   ...            ...     ...           ...         ...      ...
# 401       2     1              1       1             4       46.22   9.2440
# 86        2     1              1       1             1       76.52  19.1300
# 842       0     2              0       0             5       39.47   3.9470
# 889       0     2              0       1             5       76.92  38.4600
# 817       0     2              1       1             2       33.88  13.5520
#
# ...

# %%
y_train
# Out:
# 347     8
# 632     2
# 10      4
# 688     2
# 630    10
#        ..
# 896     7
# 917     4
# 73      6
# 933     7
# 303     4
# Name: Quantity, Length: 800, dtype: int64

# %%
y_test
# Out:
# 575     7
# 210     9
# 544     1
# 33      2
# 225     2
#        ..
# 401     4
# 86      5
# 842     2
# 889    10
# 817     8
# Name: Quantity, Length: 200, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
Lr = LinearRegression()

# %%
Lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_predictions = Lr.predict(x_test)

# %%
y_predictions
# Out:
# array([4.71274217, 5.39124501, 5.9127372 , 5.27950069, 5.42593677,
#        5.27168819, 5.90829473, 5.52316902, 5.04116334, 5.73327413,
#        5.69919032, 6.10360723, 4.34714771, 5.82844885, 5.52287285,
#        5.4417862 , 5.40711007, 5.56341618, 5.77998081, 5.83466831,
#        6.01731745, 4.69356319, 5.8750916 , 4.92823436, 5.95013493,
#        6.27098365, 5.72168322, 5.66001561, 5.19889416, 5.17853052,
#        5.79205183, 6.32656781, 5.20901987, 5.15468464, 5.60923436,
#        6.5975078 , 5.54915978, 5.18445382, 5.50080396, 5.47044245,
#        5.18445382, 5.5355362 , 5.03494388, 5.32146873, 6.18315694,
#        5.17793819, 5.00635936, 4.52057527, 5.80501135, 6.4770703 ,
#        5.53903407, 4.97807882, 5.21599998, 4.8539595 , 5.03294245,
#        6.20617044, 4.86047513, 5.70404118, 5.830522  , 4.88965197,
#        5.18504615, 5.21037285, 4.47540552, 6.03264629, 5.28116547,
#        5.84679544, 6.30904544, 4.94089771, 5.01761362, 6.21451916,
# ...

# %% [markdown]
# # **ACCURACY SCORE**

# %%
Lr.score(X_train,y_train)
# Out:
# 0.02326165157080362

# %%
import statistics

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_predictions)
# Out:
# 9.981429000198448

# %%
corrmat = df1.corr()
top_corelation_features = corrmat.index
plt.figure(figsize=(30,30))

g = sns.heatmap(df1[top_corelation_features].corr(),annot=True,cmap='YlGnBu')

# %%
plt.figure(figsize=(10,5))
plt.scatter(y_test, y_predictions,color ='blue')
plt.xlabel('Actual Sales',fontdict={'fontsize':20,'color':'Red','fontweight':10})
plt.ylabel('Predicted Sales',fontdict={'fontsize':20,'color':'Yellow','fontweight':10})
plt.title('Actual vs Predicted Sales',fontdict={'fontsize':25,'color':'black','fontweight':10})
plt.show()

# %% [markdown]
# # ***ThAnk yOU*** 😊
